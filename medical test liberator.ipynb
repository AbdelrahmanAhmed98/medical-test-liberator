# %%
import sys
import time
import random
from random import randint
import webbrowser

# %%
def first():
    ALT = 'ALT (Alanine Transaminase) هو جزء من اختبار وظائف الكبد'
    ANA = 'الأجسام المضادة للنواة: اختبار للتأكيد أو الاستبعاد لاضطرابات المناعة الذاتية التي يشتبه بها'
    AST = 'AST (Alanine Aminotransferase) إنزيم ؛ يستخدم لفحص ومراقبة اضطرابات الكبد'
    BAC = 'تركيز الكحول في الدم / المحتوى (النسبة المئوية للكحول في الدم ؛ اختبارات لمستوى التسمم)'
    BNP = 'Beta Natriuretic Peptide: اختبار لقصور القلب الاحتقاني'
    BUN = 'نيتروجين اليوريا في الدم (اختبارات وظائف الكبد والكلى)'
    CA = 'الكالسيوم (يقيس مستويات الكالسيوم في الدم)'
    CK = 'الكرياتين فوسفوكيناز (اختبار لتلف العضلات)'
    CR = 'الكرياتينين (جزء من اختبار وظائف الكلى ؛ يقيس النفايات في الدم)'
    ESR = 'معدل ترسيب كرات الدم الحمراء (اختبارات للالتهاب)'
    HCT = 'الهيماتوكريت: جزء من اختبار CBC القياسي ؛ يمكن أن تشير القياسات غير الطبيعية إلى المرض'
    Hgb = 'الهيموغلوبين (يقيس مستويات الهيموغلوبين ، ويستخدم لتشخيص فقر الدم)'
    LDL = 'البروتينات الدهنية قليلة الكثافة (اختبار الكوليسترول الضار)'
    HDL = 'البروتينات الدهنية عالية الكثافة (اختبار الكوليسترول الجيد)'
    INR = 'المعدل الطبيعي الدولي (يقيس معدل تخثر الدم ؛ اختبارات لاضطرابات الدم أو لتعديل أدوية ترقق الدم)'
    K = 'البوتاسيوم (اختبار لمستويات البوتاسيوم ؛ المستويات المرتفعة أو المنخفضة يمكن أن تؤدي إلى مشاكل خطيرة)'
    MG = 'المغنيسيوم (اختبار لمستويات المغنيسيوم: بعض المستويات المطلوبة للجسم ليعمل بشكل صحيح)'
    NA = 'الصوديوم (اختبار مستويات الصوديوم في الدم ؛ ضروري لوظائف الأعصاب والجسم المناسبة)'
    PSA = 'مستضد البروستات النوعي (اختبار سرطان البروستاتا)'
    PT = 'وقت البروثرومبين اختبار تخثر الدم مع INR أو النسبة الطبيعية الدولية'
    RBC = 'CBC عدد خلايا الدم الحمراء وهو جزء من اختبار  )'
    TPO = 'الأجسام المضادة لبيروكسيداز الغدة الدرقية (اختبار الأجسام المضادة للغدة الدرقية ، مما يشير إلى مرض الغدة الدرقية)'
    TRIG = 'جزء من اختبار الكوليسترول'
    TSH = 'هرمون تحفيز الغدة الدرقية (يقيس كمية هرمون الغدة الدرقية في الدم)'
    WBC = 'CBC عدد خلايا الدم البيضاء وهو جزء من اختبار '
    FBS = 'سكر الدم الصائم (الجلوكوز)'
    CU = 'النحاس'
    CMV = 'فيروس مضخم للخلايا'
    
    
    test_type = input('please enter your test type: \nEx: WBC: ')
    if test_type == ('ALT'):
        print(ALT)
        percentage = float(input('please enter your test Result: \nEx: 25:'))

        if percentage >= 7 and percentage <= 55:
            print ('your ALT test is normal \nNormal Rate (7-55)')
        else:
            print('your ALT test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (7-55)')
        first()   
    elif test_type == ('ANA'):
        print(ANA)

        percentage = float(input('please enter your test Result: \nEx: 1.50: '))

        if percentage >= 1.40 and percentage <= 1.60:
            print ('your ANA test is normal \nNormal Rate (1.40-1.60)')
        else:
            print('your ANA test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (1.40-1.60)')

        first()
    
    elif test_type == ('AST'):
        print(AST)
        percentage = float(input('please enter your test Result: \nEx: 20: '))
        if percentage >= 10 and percentage <= 40:
            print ('your AST test is normal \nNormal Rate (10-40)')
        else:
            print('your AST test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (10-40)')
        first() 
        
        
    elif test_type == ('BAC'):
        print(BAC)
        percentage = float(input('please enter your test Result: \nEx: 1: '))
        if percentage <= 0.08:
            print ('your BAC test is normal \nNormal Rate (0-0.08maximum)')
        else:
            print('your BAC test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (0-0.08maximum)')
        first()
        
    
    elif test_type == ('BNP'):
        print(BNP)
        percentage = float(input('please enter your test Result: \nEx: 100: '))
        if percentage <= 100:
            print ('your BNP test is normal \nNormal Rate (less than 100, High: More than 400 pg/mL, Between 100 to 400 pg/mL requires a doctor’s evaluation)')
        else:
            print('your BNP test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (less than 100, High: More than 400 pg/mL, Between 100 to 400 pg/mL requires a doctor’s evaluation)')
        first()
        
    elif test_type == ('BUN'):
        print(BUN)
        percentage = float(input('please enter your test Result(in mg/dL): \nEx: 20: '))
        if percentage >= 7 and percentage <= 20:
            print ('your BUN test is normal \nNormal Rate (around 7 to 20 mg/dL)')
        else:
            print('your BUN test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (around 7 to 20 mg/dL)')
        first()
    
    elif test_type == ('CA'):
        print(CA)
        percentage = float(input('please enter your test Result(in mg/dL): \nEx: 9.2: '))
        if percentage >= 8.6 and percentage <= 10.3:
            print ('your CA test is normal \nNormal Rate (around 8.6 to 10.3 mg/dL)')
        else:
            print('your CA test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (around 8.6 to 10.3 mg/dL)')
        first()
        
    elif test_type == ('CK'):
        print(CK)
        percentage = float(input('please enter your test Result(in u/l): \nEx: 50: '))
        if percentage >= 22 and percentage <= 198:
            print ('your CK test is normal \nNormal Rate (22 to 198 U/L (units per liter))')
        else:
            print('your CK test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (22 to 198 U/L (units per liter)')
        first()
        
        
    elif test_type == ('CR'):
        print(CR)
        percentage = float(input('please enter your test Result(in mg/dL): \nEx: 1.2: '))
        if percentage >= 0.59 and percentage <= 1.04:
            print ('your CR test is normal \nNormal Rate ( For adult men, 0.74 to 1.35 mg/dL (65.4 to 119.3 micromoles/L), For adult women, 0.59 to 1.04 mg/dL (52.2 to 91.9 micromoles/L)))')
        else:
            print('your CR test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (For adult men, 0.74 to 1.35 mg/dL (65.4 to 119.3 micromoles/L), For adult women, 0.59 to 1.04 mg/dL (52.2 to 91.9 micromoles/L')
        first()
    
    
    elif test_type == ('ESR'):
        print(ESR)
        percentage = float(input('please enter your test Result(in mm/hr): \nEx: 10: '))
        if percentage >= 0 and percentage <= 22:
            print ('your ESR test is normal \nNormal Rate (0 to 22 mm/hr for men and 0 to 29 mm/hr for women)))')
        else:
            print('your ESR test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (0 to 22 mm/hr for men and 0 to 29 mm/hr for women)')
        first()
        
    elif test_type == ('HCT'):
        print(HCT)
        percentage = float(input('please enter your test Result: \nEx: 40: '))
        if percentage >= 36 and percentage <= 48:
            print ('your HCT test is normal \nNormal Rate (for men range from 41% to 50%. Normal level for women is 36% to 48%.)))')
        else:
            print('your HCT test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (for men range from 41% to 50%. Normal level for women is 36% to 48%.)')
        first()
    
    elif test_type == ('Hgb'):
        print(Hgb)
        percentage = float(input('please enter your test Result: \nEx: 13: '))
        if percentage >= 12 and percentage <= 15.5:
            print ('your Hgb test is normal \nNormal Rate (For men, 13.5 to 17.5 grams per deciliter. For women, 12.0 to 15.5 grams per deciliter)))')
        else:
            print('your Hgb test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (For men, 13.5 to 17.5 grams per deciliter. For women, 12.0 to 15.5 grams per deciliter)')
        first()
    elif test_type == ('LDL'):
        print(LDL)
        percentage = float(input('please enter your test Result: \nEx: 50: '))
        if percentage < 100:
            print ('your LDL test is normal \nNormal Rate (Less than 100mg/dL)))')
        else:
            print('your LDL test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (Less than 100mg/dL)')
        first()
    elif test_type == ('HDL'):
        print(HDL)
        percentage = float(input('please enter your test Result: \nEx: 50: '))
        if percentage >= 40:
            print ('your HDL test is normal \nNormal Rate (40mg/dL or higher)))')
        else:
            print('your HDL test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (40mg/dL or higher)')
        first()
    elif test_type == ('INR'):
        print(INR)
        percentage = float(input('please enter your test Result: \nEx: 0.9: '))
        if percentage <= 1.1:
            print ('your INR test is normal \nNormal Rate (1.1 or below)))')
        else:
            print('your INR test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (1.1 or below)')
        first()
    elif test_type == ('K'):
        print(K)
        percentage = float(input('please enter your test Result (in mmol/L): \nEx: 4: '))
        if percentage >= 3.5 and percentage <= 5:
            print ('your K test is normal \nNormal Rate (between 3.5 and 5.0 millimoles per liter (mmol/L))))')
        else:
            print('your K test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (between 3.5 and 5.0 millimoles per liter (mmol/L))')
        first()
        
    elif test_type == ('MG'):
        print(MG)
        percentage = float(input('please enter your test Result (in mg/dl): \nEx: 2.1: '))
        if percentage >= 1.7 and percentage <= 2.8:
            print ('your MG test is normal \nNormal Rate (Men 	1.7-2.8 mg/dl 	0.70-1.15 mmol/L, Women 	2-3 mg/dl 	0.82-1.24 mmol/L, Pregnancy 	1.6-2.1 mg/dl 	0.66-0.86 mmol/L)))')
        else:
            print('your MG test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (Men 	1.7-2.8 mg/dl 	0.70-1.15 mmol/L, Women 	2-3 mg/dl 	0.82-1.24 mmol/L, Pregnancy 	1.6-2.1 mg/dl 	0.66-0.86 mmol/L)')
        first()
    
    elif test_type == ('NA'):
        print(NA)
        percentage = float(input('please enter your test Result (in mmol/L): \nEx: 140: '))
        if percentage >= 135 and percentage <= 145:
            print ('your NA test is normal \nNormal Rate (between 135 and 145 milliequivalents per liter (mEq/L)))')
        else:
            print('your NA test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (between 135 and 145 milliequivalents per liter (mEq/L))')
        first()
    
    elif test_type == ('PSA'):
        print(PSA)
        percentage = float(input('please enter your test Result (in mmol/L): \nEx: 1.5: '))
        if percentage >= 0 and percentage <= 2.5:
            print ('your PSA test is normal \nNormal Rate (between 0 and 2.5 ng/ml), and the best rate for youth is The normal range is between 1.0 and 1.5 ng/ml.')
        else:
            print('your PSA test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (between 0 and 2.5 ng/ml), and the best rate for youth is The normal range is between 1.0 and 1.5 ng/ml.')
        first()
    
    elif test_type == ('PT'):
        print(PT)
        percentage = float(input('please enter your test Result (in seconds): \nEx: 12: '))
        if percentage >= 11 and percentage <= 12.5:
            print ('your PT test is normal \nNormal Rate (11.0-12.5 seconds; 85%-100%)')
        else:
            print('your PT test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (11.0-12.5 seconds; 85%-100%)')
        first()
    elif test_type == ('RBC'):
        print(RBC)
        percentage = float(input('please enter your test Result (in cells/mcL): \nEx: 5: '))
        if percentage >= 4.2 and percentage <= 5.4:
            print ('your RBC test is normal \nNormal Rate (men – 4.7 to 6.1 million cells per microlitre (cells/mcL) women – 4.2 to 5.4 million cells/mcL.)')
        else:
            print('your RBC test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (men – 4.7 to 6.1 million cells per microlitre (cells/mcL) women – 4.2 to 5.4 million cells/mcL.)')
        first()
        
    elif test_type == ('TPO'):
        print(TPO)
        percentage = float(input('please enter your test Result (in IU/mL): \nEx: 1.5: '))
        if percentage < 16:
            print ('your TPO test is normal \nNormal Rate (below 16 IU/mL)')
        else:
            print('your TPO test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (below 16 IU/mL)')
        first()
        
    elif test_type == ('TRIG'):
        print(TRIG)
        percentage = float(input('please enter your test Result (in milligrams per deciliter (mg/dL)): \nEx: 100: '))
        if percentage < 150:
            print ('your Triglycerides test is normal \nNormal Rate (Less than 150 milligrams per deciliter (mg/dL), or less than 1.7 millimoles per liter (mmol/L) )')
        else:
            print('your Triglycerides test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (Less than 150 milligrams per deciliter (mg/dL), or less than 1.7 millimoles per liter (mmol/L) )')
        first()
        
    elif test_type == ('TSH'):
        print(TSH)
        percentage = float(input('please enter your test Result (in mIU/L): \nEx: 2.5: '))
        if percentage >= 0.5 and percentage <= 5:
            print ('your TSH test is normal \nNormal Rate (0.5 to 5.0 mIU/L)')
        else:
            print('your TSH test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (0.5 to 5.0 mIU/L)')
        first()
    
    elif test_type == ('WBC'):
        print(WBC)
        percentage = float(input('please enter your test Result (in liter (× 109/L)): \nEx: 5: '))
        if percentage >= 4.5 and percentage <= 11:
            print ('your WBC test is normal \nNormal Rate (4,500 to 11,000 WBCs per microliter (4.5 to 11.0 × 109/L))')
        else:
            print('your WBC test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (4,500 to 11,000 WBCs per microliter (4.5 to 11.0 × 109/L))')
        first()
        
    elif test_type == ('FBS'):
        print(FBS)
        percentage = float(input('please enter your test Result (in mg/dL): \nEx: 100: '))
        if percentage >= 90 and percentage <= 110:
            print ('your FBS test is normal \nNormal Rate (90 to 110 mg/dL)')
        else:
            print('your FBS test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (90 to 110 mg/dL)')
        first()
        
    elif test_type == ('CU'):
        print(CU)
        percentage = float(input('please enter your test Result (in mg/dL): \nEx: 100: '))
        if percentage >= 85 and percentage <= 180:
            print ('your CU test is normal \nNormal Rate (is 85 to 180 micrograms per deciliter (mcg/dL).)')
        else:
            print('your CU test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (is 85 to 180 micrograms per deciliter (mcg/dL).)')
        first()
    
    elif test_type == ('CMV'):
        print(CMV)
        percentage = float(input('please enter your test Result (in mg/dL): \nEx: 800: '))
        if percentage >= 620 and percentage <= 1400:
            print ('your CMV test is normal \nNormal Rate (is 620 to 1400 mg/dl')
        else:
            print('your CMV test is UP Normal, please visit the doctor as soon as possible \nNormal Rate (is 620 to 1400 mg/dl)')
        first()
first()
# Out:
# please enter your test type:
# Ex: WBC: WBC
# CBC عدد خلايا الدم البيضاء وهو جزء من اختبار
# please enter your test Result (in liter (× 109/L)):
# Ex: 5: 5
# your WBC test is normal
# Normal Rate (4,500 to 11,000 WBCs per microliter (4.5 to 11.0 × 109/L))
# please enter your test type:
# Ex: WBC: WBC
# CBC عدد خلايا الدم البيضاء وهو جزء من اختبار
# please enter your test Result (in liter (× 109/L)):
# Ex: 5: 20
# your WBC test is UP Normal, please visit the doctor as soon as possible
# Normal Rate (4,500 to 11,000 WBCs per microliter (4.5 to 11.0 × 109/L))
